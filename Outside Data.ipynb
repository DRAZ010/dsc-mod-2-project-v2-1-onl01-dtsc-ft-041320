# %%
import pandas as pd

# %%
df_region = pd.read_csv('data/regions.csv')
df_region.head()
# Out:
#    Region Name   Region Type       Type zillow_Current  \
# 0  King County        county  All Homes       $667,300
# 1        Adams  neighborhood  All Homes       $723,500
# 2     Adelaide  neighborhood  All Homes       $486,900
# 3     Adelaide  neighborhood  All Homes     $1,350,100
# 4      Admiral  neighborhood  All Homes       $834,900
#
#   zillow_Month Over Month zillow_Quarter Over Quarter zillow_Year Over Year  \
# 0                    0.9%                        2.7%                  4.5%
# 1                    0.5%                        1.2%                 -2.4%
# 2                    1.1%                        3.5%                  7.6%
# 3                    1.2%                        3.7%                  5.0%
# 4                    0.6%                        2.1%                  3.6%
#
#   5 Year Annualized 10 Year Annualized Current Month Over Month  \
# 0              8.8%               6.0%    $546             0.7%
# ...

# %%
df_zip = pd.read_csv('data/zipcode.csv')
df_zip.head()
# Out:
#    Region Name Region Type       Type     Current Month Over Month  \
# 0  King County      county  All Homes    $667,300             0.9%
# 1        98001     zipcode  All Homes    $432,800             1.2%
# 2        98002     zipcode  All Homes    $358,500             1.3%
# 3        98003     zipcode  All Homes    $392,800             1.2%
# 4        98004     zipcode  All Homes  $1,613,200             0.8%
#
#   Quarter Over Quarter Year Over Year 5 Year Annualized 10 Year Annualized
# 0                 2.7%           4.5%              8.8%               6.0%
# 1                 3.9%           9.4%              9.1%               4.9%
# 2                 4.1%          11.5%             10.3%               5.1%
# 3                 3.7%          10.1%              9.7%               5.3%
# 4                 2.5%           4.9%              9.8%               7.1%
