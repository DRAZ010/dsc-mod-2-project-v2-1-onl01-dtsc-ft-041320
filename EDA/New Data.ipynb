# %% [markdown]
# # DO NOT RUN!!!

# %%
import pandas as pd

# %%
header_list = ['Region Name',
 'Region Type',
 'Type',
 'zillow_Current',
 'zillow_Month Over Month',
 'zillow_Quarter Over Quarter',
 'zillow_Year Over Year',
 '5 Year Annualized',
 '10 Year Annualized',
 'Current',
 'Month Over Month',
 'Quarter Over Quarter',
 'Year Over Year']

# %%
df = pd.read_csv('data/kc_neighborhood_import.csv', names=header_list)
df.head()
# Out:
#                    Region Name   Region Type       Type  \
# 0  King County, WA - All Homes           NaN        NaN
# 1                    Statistic           NaN        NaN
# 2                  Region Name   Region Type       Type
# 3                  King County        county  All Homes
# 4                        Adams  neighborhood  All Homes
#
#             zillow_Current zillow_Month Over Month  \
# 0                      NaN                     NaN
# 1  Zillow Home Value Index                     NaN
# 2                  Current        Month Over Month
# 3                 $667,300                    0.9%
# 4                 $723,500                    0.5%
#
#   zillow_Quarter Over Quarter zillow_Year Over Year  5 Year Annualized  \
# 0                         NaN                   NaN                NaN
# 1                         NaN                   NaN                NaN
# 2        Quarter Over Quarter        Year Over Year  5 Year Annualized
# ...

# %%
def get_col_names():
    list = []
    for val in df2.iloc[1]:
        list.append(val)
    return list

# %%
get_col_names()
# Out:
# ['Region Name',
#  'Region Type',
#  'Type',
#  'Current',
#  'Month Over Month',
#  'Quarter Over Quarter',
#  'Year Over Year',
#  '5 Year Annualized',
#  '10 Year Annualized',
#  'Current',
#  'Month Over Month',
#  'Quarter Over Quarter',
#  'Year Over Year']

# %%
df.to_csv('data/region.csv', index=False)

# %%
df2 = pd.read_csv('data/king-county-wa-ZIP codes-Report.csv', names=header_list2)
df2.head()
# Out:
#                    Region Name  Region Type       Type  \
# 0  King County, WA - All Homes          NaN        NaN
# 1                    Statistic          NaN        NaN
# 2                  Region Name  Region Type       Type
# 3                  King County       county  All Homes
# 4                        98001      zipcode  All Homes
#
#                    Current  Month Over Month  Quarter Over Quarter  \
# 0                      NaN               NaN                   NaN
# 1  Zillow Home Value Index               NaN                   NaN
# 2                  Current  Month Over Month  Quarter Over Quarter
# 3                 $667,300              0.9%                  2.7%
# 4                 $432,800              1.2%                  3.9%
#
#    Year Over Year  5 Year Annualized  10 Year Annualized
# 0             NaN                NaN                 NaN
# 1             NaN                NaN                 NaN
# ...

# %%
get_col_names()
# Out:
# ['Region Name',
#  'Region Type',
#  'Type',
#  'Current',
#  'Month Over Month',
#  'Quarter Over Quarter',
#  'Year Over Year',
#  '5 Year Annualized',
#  '10 Year Annualized']

# %%
header_list2 = ['Region Name',
 'Region Type',
 'Type',
 'Current',
 'Month Over Month',
 'Quarter Over Quarter',
 'Year Over Year',
 '5 Year Annualized',
 '10 Year Annualized']

# %%
df2.to_csv('data/kc_zipcodes.csv', index=False)

# %%
region = pd.read_csv('data/region.csv')
region.head()
# Out:
#                    Region Name   Region Type       Type  \
# 0  King County, WA - All Homes           NaN        NaN
# 1                    Statistic           NaN        NaN
# 2                  Region Name   Region Type       Type
# 3                  King County        county  All Homes
# 4                        Adams  neighborhood  All Homes
#
#             zillow_Current zillow_Month Over Month  \
# 0                      NaN                     NaN
# 1  Zillow Home Value Index                     NaN
# 2                  Current        Month Over Month
# 3                 $667,300                    0.9%
# 4                 $723,500                    0.5%
#
#   zillow_Quarter Over Quarter zillow_Year Over Year  5 Year Annualized  \
# 0                         NaN                   NaN                NaN
# 1                         NaN                   NaN                NaN
# 2        Quarter Over Quarter        Year Over Year  5 Year Annualized
# ...

# %%
zipcode = pd.read_csv('data/kc_zipcodes.csv')
zipcode
# Out:
#                     Region Name  Region Type       Type  \
# 0   King County, WA - All Homes          NaN        NaN
# 1                     Statistic          NaN        NaN
# 2                   Region Name  Region Type       Type
# 3                   King County       county  All Homes
# 4                         98001      zipcode  All Homes
# ..                          ...          ...        ...
# 83                        98199      zipcode  All Homes
# 84                        98224      zipcode  All Homes
# 85                        98251      zipcode  All Homes
# 86                        98288      zipcode  All Homes
# 87                        98354      zipcode  All Homes
#
#                     Current  Month Over Month  Quarter Over Quarter  \
# 0                       NaN               NaN                   NaN
# 1   Zillow Home Value Index               NaN                   NaN
# 2                   Current  Month Over Month  Quarter Over Quarter
# ...

# %%
region.drop(labels=[0, 1, 2], inplace=True)

# %%
region.to_csv('data/regions.csv', index=False)

# %%
zipcode.drop(labels=[0, 1, 2], inplace=True)

# %%
zipcode.to_csv('data/zipcode.csv', index=False)
