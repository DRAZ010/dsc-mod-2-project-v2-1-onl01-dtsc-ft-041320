# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('kc_house_data.csv')
print(df.shape)
df.head()
# Out:
# (21597, 21)
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
# ...

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement     object
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
zip_count = df['zipcode']
zip_count.nunique()
# Out:
# 70

# %% [markdown]
# ## Filling Null Values

# %%
df['waterfront'].fillna('0.0', inplace=True)
df['view'].fillna('0.0', inplace=True)
df['yr_renovated'].fillna('0', inplace=True)

# %% [markdown]
# ### Dropping ID Column

# %% [markdown]
# cols = ['id']
# df_clean = df.drop(cols, axis = 1)
# df_clean.head()

# %% [markdown]
# #### Random
# * '?' in df_clean[sqft_basement]
# *

# %%
df_clean = df

# %%
df_clean.loc[df_clean['sqft_basement'] == '?']
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# 18       16000397   12/5/2014   189000.0         2       1.00         1200
# 42     7203220400    7/7/2014   861990.0         5       2.75         3595
# 79     1531000030   3/23/2015   720000.0         4       2.50         3450
# 112    2525310310   9/16/2014   272500.0         3       1.75         1540
# ...           ...         ...        ...       ...        ...          ...
# 21442  3226049565   7/11/2014   504600.0         5       3.00         2360
# 21447  1760650900   7/21/2014   337500.0         4       2.50         2330
# 21473  6021503707   1/20/2015   352500.0         2       2.50          980
# 21519  2909310100  10/15/2014   332000.0         4       2.50         2380
# 21581   191100405   4/21/2015  1580000.0         4       3.25         3410
#
#        sqft_lot  floors waterfront view  ...  grade  sqft_above  \
# ...

# %%
df_clean['sqft_basement'] = df_clean['sqft_basement'].apply(lambda x: x.replace('?', '0'))

# %%
df_clean.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0        0.0    0  ...      7        1180            0.0
# 1      7242     2.0          0    0  ...      7        2170          400.0
# 2     10000     1.0          0    0  ...      6         770            0.0
# 3      5000     1.0          0    0  ...      7        1050          910.0
# 4      8080     1.0          0    0  ...      8        1680            0.0
#
#   yr_built  yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
def get_binary_column(dfName, colName, qual_for_false):
    newCol = []
    for val in dfName[colName]:
        if val <= qual_for_false:
            newCol.append('0')
        else:
            newCol.append('1')
    return newCol

# %%
df_clean['has_basement'] = get_binary_column(df_clean, 'sqft_basement', '0.0')

# %%
df_clean.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront view  ...  sqft_above  sqft_basement  yr_built  \
# 0      5650     1.0        0.0    0  ...        1180            0.0      1955
# 1      7242     2.0          0    0  ...        2170          400.0      1951
# 2     10000     1.0          0    0  ...         770            0.0      1933
# 3      5000     1.0          0    0  ...        1050          910.0      1965
# 4      8080     1.0          0    0  ...        1680            0.0      1987
#
#   yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# # According to KC housing website, anything above grade 10 is a custom built home

# %%
df_clean['is_cust_build'] = get_binary_column(df_clean, 'grade', 11)
df_clean['is_cust_build'].nunique()
# Out:
# 2

# %%
df_clean.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront view  ...  sqft_basement  yr_built  \
# 0      5650     1.0        0.0    0  ...            0.0      1955
# 1      7242     2.0          0    0  ...          400.0      1951
# 2     10000     1.0          0    0  ...            0.0      1933
# 3      5000     1.0          0    0  ...          910.0      1965
# 4      8080     1.0          0    0  ...            0.0      1987
#
#    yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0   98178  47.5112 -122.257           1340        5650
# ...

# %%
df_clean.to_csv('kc_cleaned_data.csv', index=False)
